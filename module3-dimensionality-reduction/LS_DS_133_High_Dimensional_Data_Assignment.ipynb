# %% [markdown]
# # Vertical Line Test

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import math
plt.rcParams.update({'font.size': 14})

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
# Passes with flying colors
x = np.arange(-15, 16)
y = x**4 + 2.5*x
plt.plot(x, y, color='#469496')  
plt.axvline(x=0, color='#B56917');

# %%
# Woah Woah Woah Woah Woah Woah Woah lois this dosen't pass
theta = np.arange(0, 10*np.pi, 0.01)

for s in np.arange(0, 1):
    x = 1*np.cos(theta + s)*np.exp(.2*theta)
    y = 1*np.sin(theta + s)*np.exp(.2*theta)
    p1 = plt.plot(x, y, color='#8FD400')
plt.axvline(x=.5, color='#FCD667');

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %%
# A function has only one output value for each input value.
# f(3) can't equal 5 while f(2) also equals 5 something is not right there

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %%
# Only Relation 5 is a function
relation1 = np.array([[1,3,1 ],[2,2,3]])
r1l = mpatches.Patch(color='#D92121', label='Relation 1')
relation2 = np.array([[1,2,6],[3,3,7]])
r2l = mpatches.Patch(color='#FFEB00', label='Relation 2')
relation3 = np.array([[9,2,9],[4,1,6]])
r3l = mpatches.Patch(color='#5E8C31', label='Relation 3')
relation4 = np.array([[6,8,6],[2,3,4]])
r4l = mpatches.Patch(color='#0066CC', label='Relation 4')
relation5 = np.array([[2,2,2],[6,7,4]])
r5l = mpatches.Patch(color='#8F47B3', label='Relation 5')

fig = plt.figure(figsize=(9, 10))
for x, y, colors in [(relation1[0],relation1[1], '#D92121'),(relation2[0],relation2[1], '#FFEB00'),(relation3[0],relation3[1], '#5E8C31'),(relation4[0],relation4[1], '#0066CC'),(relation5[0],relation5[1], '#8F47B3'),]:
    plt.grid()
    plt.scatter(x, y, s=100)
    plt.plot(x,y, color=colors);
plt.legend(handles=[r1l, r2l, r3l, r4l, r5l])
plt.show();

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %%
def m(x):
    return x[0]+x[1], x[0]+x[2], x[1]+x[2]
x=[]
y=[]
for point in [(20,30,5), (30,40,10), (40,50,15)]:
    plt.scatter(x=point[0],
                y=point[1],
                s=point[2],
                c='blue');
    x.append(m(point)[0])
    y.append(m(point)[1])

print(x,y)
plt.scatter(x,y, s=100, color="red")
plt.show();
# Out:
# [50, 70, 90] [25, 40, 55]

# %% [markdown]
# \begin{align}
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %%
def n(x):
    return x[1]**2+x[2], x[1]*x[3]
x=[]
y=[]
for point in [(20,30,5), (30,40,10), (40,50,15)]:
    plt.scatter(x=point[0],
                y=point[1],
                s=point[2],
                c='blue');
    x.append(m(point)[0])
    y.append(m(point)[1])

print(x,y)
plt.scatter(x,y, s=100, color="red")
plt.show();
# Out:
# [50, 70, 90] [25, 40, 55]

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %%
# I'm honestly not sure

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
i_hat = np.array([[1],[0],[0]])
j_hat = np.array([[0],[1],[0]])
k_hat = np.array([[0],[0],[1]])

# %%
input_vector1=np.array([[3],[4]])

# %%
input_vector2=np.array([[3],[4],[5]])

# %%
def transfer(x1,y1,x2,y2):
    fig, ax = plt.subplots(figsize=(5,5))
    plt.grid()
    plt.arrow(0,0, x1, y1, head_width=.5, head_length=0.5, color ='red')
    plt.arrow(0,0, x2, y2, head_width=.5, head_length=0.5, color ='blue')
    plt.xlim(-30,30)          
    plt.ylim(-30,30)
    ax.axhline(y=0, color='k')
    ax.axvline(x=0, color='k')
    plt.show;

# %% [markdown]
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \end{align}

# %%
 def p(vect):
     x1 = vect[0][0]
     x2 = vect[1][0]
     row1 = np.array([x1 + (3*x2)])
     row2 = np.array([(2*x2) - x1])
     output_vector=np.array([row1, row2])
     return output_vector

# %%
a = p(i_hat)
b = p(j_hat)
T1 = np.column_stack([a,b])

# %%
print(f'''
i^hat:
{a}

j^hat:
{b}''')
# Out:
# i^hat:
# [[ 1]
#  [-1]]
#
# j^hat:
# [[3]
#  [2]]

# %%
pd.DataFrame(T1)
# Out:
#    0  1
# 0  1  3
# 1 -1  2

# %%
p(input_vector1)
# Out:
# array([[15],
#        [ 5]])

# %%
output_vector1 = np.matmul(T1, input_vector1)
output_vector1
# Out:
# array([[15],
#        [ 5]])

# %%
transfer(input_vector1[0][0], input_vector1[1][0], output_vector1[0][0], output_vector1[1][0])

# %% [markdown]
# \begin{align}
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %%
def q(vect):
     x1 = vect[0][0]
     x2 = vect[1][0]
     x3 = vect[2][0]
     row1 = np.array([(4*x1) + x2 +(2*x3)])
     row2 = np.array([(2*x2) - x1 + (3*x3)])
     row3 = np.array([(5*x1) - (2*x3) + x2])
     output_vector=np.array([row1, row2, row3])
     return output_vector

# %%
c = q(i_hat)
d = q(j_hat)
e = q(k_hat)
T2 = np.column_stack([c,d,e])

# %%
print(f'''
i^hat:
{c}

j^hat:
{d}

k^hat:
{e}''')
# Out:
# i^hat:
# [[ 4]
#  [-1]
#  [ 5]]
#
# j^hat:
# [[1]
#  [2]
#  [1]]
#
# k^hat:
# [[ 2]
#  [ 3]
#  [-2]]

# %%
pd.DataFrame(T2)
# Out:
#    0  1  2
# 0  4  1  2
# 1 -1  2  3
# 2  5  1 -2

# %%
q(input_vector2)
# Out:
# array([[26],
#        [20],
#        [ 9]])

# %%
output_vector2 = np.matmul(T2, input_vector2)
output_vector2
# Out:
# array([[26],
#        [20],
#        [ 9]])

# %%
transfer(input_vector2[0][0], input_vector2[1][0], output_vector2[0][0], output_vector2[1][0])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %%
# Eigenvalues and eigenvectors can be used to lower the dimensionality of any Square matrix by diagonalizing it.
# Eigenvectors are vectors that don't change their line (the direction, and/or span can change be it will always be on their line)
# Eigenvalues is just the scalar to the eigenvector

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %%
# What is the curse of dimensionality?
# When your data has too many features.

# %%
# The challenges are:
# Data overfitting
# Data starts thinning out
# The more dimensions the harder it is to visualize the data

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?

# %%
# The baseline rule of thumb is atleast 5 times the rows as columns

# %%
# Solutions
# Get rid of redundant data
# Get More Data (easier said than done)
# Don't measure similaritys via Euclidean Distance

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %% [markdown]
# <h3><strong> Questions to ask:<br> What would be the subset for this dataset???<br>
# <strong>Also I'm losing over 50% of my data how can I improve that???</strong></h3>

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read Natinal Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.head()
# Out:
# (64535, 99)
#           CONTROL  AGE1 METRO3  ...          FMTBURDEN  FMTREGION  FMTSTATUS
# 0  '100003130103'    82    '3'  ...     '2 30% to 50%'       '-5'       '-5'
# 1  '100006110249'    50    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 2  '100006370140'    53    '5'  ...    '3 50% or More'       '-5'       '-5'
# 3  '100006520140'    67    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 4  '100007130148'    26    '1'  ...  '1 Less than 30%'       '-5'       '-5'
#
# [5 rows x 99 columns]

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.tail(5)
# Out:
# (64535, 99)
#        CONTROL  AGE1  METRO3  ...  FMTBURDEN  FMTREGION  FMTSTATUS
# 64530    64530    55       0  ...          3          1          0
# 64531    64531    37       0  ...          1          0          0
# 64532    64532    23       1  ...          3          1          0
# 64533    64533    57       0  ...          1          1          0
# 64534    64534    66       3  ...          1          0          0
#
# [5 rows x 99 columns]

# %%
# Now we only ahve numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %%
cat_cols = national_processed.columns[national_processed.dtypes=='object']
num_cols = national_processed.columns[national_processed.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 0 categorical columns
# 99 numerical columns

# %%
from sklearn.preprocessing import StandardScaler
feature_cols = national_processed.columns[1:]
feature_cols[:5]
# Out:
# Index(['AGE1', 'METRO3', 'REGION', 'LMED', 'FMR'], dtype='object')

# %%
x = national_processed.loc[:, feature_cols].values
# fit the scaler to the known mean and std of each value of x(feature_cols)
x = StandardScaler().fit_transform(x)

# %%
print('{:.2f}'.format(np.mean(x)))
print(round(np.std(x)))
# Out:
# 0.00
# 1.0

# %%
normal_national = pd.DataFrame(x, columns=feature_cols)
normal_national.sample(5)
# Out:
#            AGE1    METRO3    REGION  ...  FMTBURDEN  FMTREGION  FMTSTATUS
# 11658 -0.042368 -0.178959 -0.375587  ...  -0.544709  -0.462107        0.0
# 37077 -1.004361 -0.178959 -0.375587  ...  -0.544709  -0.462107        0.0
# 53641  1.488075  0.608784  0.576698  ...   0.549473  -0.462107        0.0
# 64153 -2.491077 -0.966702  0.576698  ...  -1.638890  -0.462107        0.0
# 12595  0.088812 -0.966702 -0.375587  ...   1.643655  -0.462107        0.0
#
# [5 rows x 98 columns]

# %%
# Find Variance-Covariance Matrix
covariance_matrix = np.cov(normal_national.T)
covariance_matrix[:1]
# Out:
# array([[ 1.0000155 ,  0.07690262, -0.03859443,  0.0231727 ,  0.0687571 ,
#         -0.01681955, -0.01670467, -0.02473836,  0.19553084,  0.07026009,
#         -0.00658997, -0.6769571 , -0.0067442 ,  0.14333578, -0.66796811,
#          0.25044328,  0.01246942,  0.12650309,  0.02064605,  0.4352433 ,
#          0.09160721,  0.42088114,  0.11591535, -0.06005873, -0.28261499,
#          0.13806317,  0.11208193,  0.07638497,  0.10225045,  0.08726681,
#          0.06622883, -0.04728604, -0.0308573 ,  0.0231727 , -0.01681955,
#         -0.01670467, -0.02473836,  0.38130209,  0.06793059,  0.06800148,
#          0.0681522 ,  0.06139312,  0.02073715,  0.12990047,  0.50601827,
#          0.15003813,  0.62380913,  0.1059814 ,  0.61844491,  0.06336382,
#          0.05987613,  0.28060875,  0.66425151,  0.06189304,  0.01053628,
#          0.0782453 ,  0.08196131,  0.2772674 ,  0.66499738,  0.07864736,
#          0.0241609 ,  0.09887278,  0.11231718,  0.27114011,  0.66608875,
# ...

# %%
# Import PCA from sklearn
from sklearn.decomposition import PCA

# %%
# Perform PCA on national and keep the best 2 columns
pca_natational = PCA(n_components=2)

# %%
# Output PCA data
pca_data = pca_natational.fit_transform(x)

# %%
pca_data
# Out:
# array([[-2.60748434, -1.38033158],
#        [ 2.01031327, -0.99201857],
#        [ 1.18484923,  0.36621931],
#        ...,
#        [ 1.86214169, -2.95179562],
#        [-4.99538419, -2.52488092],
#        [-9.86785674, -0.79890107]])

# %%
# Compare Before | After
print(f'''
National DF Before:
{national.shape}

National DF After the PCA
{pca_data.shape}
''')
# Out:
# National DF Before:
# (64535, 99)
#
# National DF After the PCA
# (64535, 2)

# %%
# principal component
df_final = pd.DataFrame(data=pca_data, columns=['PC1', 'PC2'])
df_final.head()
# Out:
#         PC1       PC2
# 0 -2.607484 -1.380332
# 1  2.010313 -0.992019
# 2  1.184849  0.366219
# 3  2.791772  1.719967
# 4 -1.600407 -0.882243

# %%
pca_natational.explained_variance_ratio_
# Out:
# array([0.34391213, 0.14590979])

# %%
sum(pca_natational.explained_variance_ratio_)
# Out:
# 0.4898219204099964

# %%
plt.figure(figsize=(10,10))
plt.xlabel('Component 1')
plt.ylabel('Component 2')
for k, c in [(0, '#36165F'), (1, '#FCCF22')]:    
    plt.scatter(df_final['PC1'], 
                df_final['PC2'], 
                s=200,
                alpha=.2,
                color=c,
                label=k);
plt.legend();

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
